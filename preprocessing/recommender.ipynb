# %% [markdown]
# ### Necessary packages

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.metrics.pairwise import linear_kernel
import pickle

# %% [markdown]
# ## Dataset

# %%
cocktails_df = pd.read_csv('final_cocktails.csv')
cocktails_df.shape
# Out:
# (1130, 5)

# %%
cocktails_df
# Out:
#                                   Cocktail  \
# 0     '57 Chevy with a White License Plate
# 1                              155 Belmont
# 2                              9 1/2 Weeks
# 3                      A Gilligan's Island
# 4                     A True Amaretto Sour
# ...                                    ...
# 1125                          Zima Blaster
# 1126                        Zizi Coin-coin
# 1127                       Zimadori Zinger
# 1128              Ziemes Martini Apfelsaft
# 1129                           Bloody Mary
#
#                                             Ingredients  \
# 0                           Creme De Cacao White, Vodka
# 1              Light Rum, Orange Juice, Vodka, Dark Rum
# 2     Orange Curacao, Strawberry Liqueur, Orange Jui...
# 3     Peach Schnapps, Cranberry Juice, Orange Juice,...
# 4                    Lemon, Maraschino Cherry, Amaretto
# ...                                                 ...
# 1125                 Chambord raspberry liqueur, Zima,
# 1126               Lemon, Ice, Lemon juice, Cointreau,
# 1127                       Zima, Midori melon liqueur,
# 1128                            Apple juice, Vermouth,
# 1129  Lime, Tabasco sauce, Worcestershire sauce, Lem...
#
#                                             Preparation Bar/Company Location
# 0     1. Fill a rocks glass with ice 2.add white cre...         NaN      NaN
# 1     Blend with ice. Serve in a wine glass. Garnish...         NaN      NaN
# 2     Combine all ingredients in glass mixer. Chill ...         NaN      NaN
# 3                                  Shaken, not stirred!         NaN      NaN
# 4     Rub the rim of an old fashioned glass with lem...         NaN      NaN
# ...                                                 ...         ...      ...
# 1125  Fill glass with ice. Pour in Chambord, then fi...         NaN      NaN
# 1126  Pour 5cl of Cointreau on ice, add 2cl of fresh...         NaN      NaN
# 1127  Pour Zima in a collins glass over ice and then...         NaN      NaN
# 1128  Serve without ice. At least the juice shold ha...         NaN      NaN
# 1129  Stirring gently, pour all ingredients into hig...         NaN      NaN
#
# [1130 rows x 5 columns]

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Check if we have any duplicates

# %%
cocktails_df['Cocktail'].describe()
# Out:
# count                                     1130
# unique                                    1130
# top       '57 Chevy with a White License Plate
# freq                                         1
# Name: Cocktail, dtype: object

# %% [markdown]
# Fill missing values with blanks

# %%
cocktails_df.fillna('', inplace=True)

# %% [markdown]
# Adding some measures and words we failed to delete to stop words

# %%
additional_stop_words = frozenset(['oz', 'simple'])

cocktail_stop_words = ENGLISH_STOP_WORDS.union(additional_stop_words)

# %% [markdown]
# ### Vectorizing text data - TFIDF

# %%
vectorizer = TfidfVectorizer(stop_words=cocktail_stop_words, token_pattern=r'\b[^\d\W][^\d\W]+\b')

tfidf_matrix = vectorizer.fit_transform(cocktails_df['Ingredients'])

# %%
cocktail_feature_df = pd.DataFrame(tfidf_matrix.toarray() ,columns=vectorizer.get_feature_names_out(), index=cocktails_df['Cocktail'])

# %% [markdown]
# ### Calculating similarities

# %%
similarity_matrix = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
similarity_df = pd.DataFrame(similarity_matrix, columns=cocktail_feature_df.index, index=cocktail_feature_df.index)

# %%
similarity_df
# Out:
# Cocktail                              '57 Chevy with a White License Plate  \
# Cocktail
# '57 Chevy with a White License Plate                              1.000000
# 155 Belmont                                                       0.110941
# 9 1/2 Weeks                                                       0.000000
# A Gilligan's Island                                               0.107361
# A True Amaretto Sour                                              0.000000
# ...                                                                    ...
# Zima Blaster                                                      0.000000
# Zizi Coin-coin                                                    0.000000
# Zimadori Zinger                                                   0.000000
# Ziemes Martini Apfelsaft                                          0.000000
# Bloody Mary                                                       0.060743
#
# Cocktail                              155 Belmont  9 1/2 Weeks  \
# Cocktail
# '57 Chevy with a White License Plate     0.110941     0.000000
# 155 Belmont                              1.000000     0.161213
# 9 1/2 Weeks                              0.161213     1.000000
# A Gilligan's Island                      0.238136     0.181296
# A True Amaretto Sour                     0.000000     0.000000
# ...                                           ...          ...
# Zima Blaster                             0.000000     0.039977
# Zizi Coin-coin                           0.038509     0.030154
# Zimadori Zinger                          0.000000     0.038257
# Ziemes Martini Apfelsaft                 0.057749     0.045220
# Bloody Mary                              0.087506     0.028612
#
# Cocktail                              A Gilligan's Island  \
# Cocktail
# '57 Chevy with a White License Plate             0.107361
# 155 Belmont                                      0.238136
# 9 1/2 Weeks                                      0.181296
# A Gilligan's Island                              1.000000
# A True Amaretto Sour                             0.000000
# ...                                                   ...
# Zima Blaster                                     0.000000
# Zizi Coin-coin                                   0.074533
# Zimadori Zinger                                  0.000000
# Ziemes Martini Apfelsaft                         0.111771
# Bloody Mary                                      0.120043
#
# Cocktail                              A True Amaretto Sour  \
# Cocktail
# '57 Chevy with a White License Plate              0.000000
# 155 Belmont                                       0.000000
# 9 1/2 Weeks                                       0.000000
# A Gilligan's Island                               0.000000
# A True Amaretto Sour                              1.000000
# ...                                                    ...
# Zima Blaster                                      0.000000
# Zizi Coin-coin                                    0.167858
# Zimadori Zinger                                   0.000000
# Ziemes Martini Apfelsaft                          0.000000
# Bloody Mary                                       0.039819
#
# Cocktail                              A.D.M. (After Dinner Mint)        A1  \
# Cocktail
# '57 Chevy with a White License Plate                    0.338618  0.000000
# 155 Belmont                                             0.062879  0.033318
# 9 1/2 Weeks                                             0.000000  0.026090
# A Gilligan's Island                                     0.060850  0.064486
# A True Amaretto Sour                                    0.000000  0.072616
# ...                                                          ...       ...
# Zima Blaster                                            0.000000  0.000000
# Zizi Coin-coin                                          0.000000  0.152675
# Zimadori Zinger                                         0.000000  0.000000
# Ziemes Martini Apfelsaft                                0.000000  0.057663
# Bloody Mary                                             0.034428  0.063581
#
# Cocktail                              Abbey Martini  Absolut Summertime  \
# Cocktail
# '57 Chevy with a White License Plate       0.000000            0.000000
# 155 Belmont                                0.148142            0.000000
# 9 1/2 Weeks                                0.199644            0.390334
# A Gilligan's Island                        0.183351            0.000000
# A True Amaretto Sour                       0.000000            0.054844
# ...                                             ...                 ...
# Zima Blaster                               0.000000            0.000000
# Zizi Coin-coin                             0.047689            0.086269
# Zimadori Zinger                            0.000000            0.000000
# Ziemes Martini Apfelsaft                   0.301417            0.000000
# Bloody Mary                                0.045251            0.020464
#
# Cocktail                              Absolutely Fabulous  ...    Zoksel  \
# Cocktail                                                   ...
# '57 Chevy with a White License Plate             0.141239  ...  0.140053
# 155 Belmont                                      0.160987  ...  0.000000
# 9 1/2 Weeks                                      0.033265  ...  0.000000
# A Gilligan's Island                              0.467562  ...  0.000000
# A True Amaretto Sour                             0.000000  ...  0.044733
# ...                                                   ...  ...       ...
# Zima Blaster                                     0.000000  ...  0.000000
# Zizi Coin-coin                                   0.049026  ...  0.070364
# Zimadori Zinger                                  0.000000  ...  0.000000
# Ziemes Martini Apfelsaft                         0.073521  ...  0.000000
# Bloody Mary                                      0.111404  ...  0.016692
#
# Cocktail                                Zombie   Zambeer  Zenmeister  \
# Cocktail
# '57 Chevy with a White License Plate  0.000000  0.000000         0.0
# 155 Belmont                           0.389660  0.000000         0.0
# 9 1/2 Weeks                           0.018410  0.000000         0.0
# A Gilligan's Island                   0.045505  0.000000         0.0
# A True Amaretto Sour                  0.000000  0.000000         0.0
# ...                                        ...       ...         ...
# Zima Blaster                          0.000000  0.000000         0.0
# Zizi Coin-coin                        0.027133  0.203998         0.0
# Zimadori Zinger                       0.000000  0.000000         0.0
# Ziemes Martini Apfelsaft              0.040690  0.000000         0.0
# Bloody Mary                           0.054429  0.000000         0.0
#
# Cocktail                              Zipperhead  Zima Blaster  \
# Cocktail
# '57 Chevy with a White License Plate    0.109736      0.000000
# 155 Belmont                             0.092073      0.000000
# 9 1/2 Weeks                             0.042990      0.039977
# A Gilligan's Island                     0.089101      0.000000
# A True Amaretto Sour                    0.000000      0.000000
# ...                                          ...           ...
# Zima Blaster                            0.627219      1.000000
# Zizi Coin-coin                          0.000000      0.000000
# Zimadori Zinger                         0.048327      0.443746
# Ziemes Martini Apfelsaft                0.000000      0.000000
# Bloody Mary                             0.050412      0.000000
#
# Cocktail                              Zizi Coin-coin  Zimadori Zinger  \
# Cocktail
# '57 Chevy with a White License Plate        0.000000         0.000000
# 155 Belmont                                 0.038509         0.000000
# 9 1/2 Weeks                                 0.030154         0.038257
# A Gilligan's Island                         0.074533         0.000000
# A True Amaretto Sour                        0.167858         0.000000
# ...                                              ...              ...
# Zima Blaster                                0.000000         0.443746
# Zizi Coin-coin                              1.000000         0.000000
# Zimadori Zinger                             0.000000         1.000000
# Ziemes Martini Apfelsaft                    0.066646         0.000000
# Bloody Mary                                 0.104804         0.000000
#
# Cocktail                              Ziemes Martini Apfelsaft  Bloody Mary
# Cocktail
# '57 Chevy with a White License Plate                  0.000000     0.060743
# 155 Belmont                                           0.057749     0.087506
# 9 1/2 Weeks                                           0.045220     0.028612
# A Gilligan's Island                                   0.111771     0.120043
# A True Amaretto Sour                                  0.000000     0.039819
# ...                                                        ...          ...
# Zima Blaster                                          0.000000     0.000000
# Zizi Coin-coin                                        0.066646     0.104804
# Zimadori Zinger                                       0.000000     0.000000
# Ziemes Martini Apfelsaft                              1.000000     0.063238
# Bloody Mary                                           0.063238     1.000000
#
# [1130 rows x 1130 columns]

# %%
similarity_df.to_pickle("similarity_df.pkl")
cocktails_df.to_pickle("cocktails_df.pkl")

# %% [markdown]
# ### Recommender Function

# %%
def cocktail_recommender(cocktail_name, num_recommendations=11, similarity_df=similarity_df, cocktails_df=cocktails_df):

  recommendations = similarity_df[cocktail_name].sort_values(ascending=False)[1:num_recommendations]
  recommendations.name = 'Similarity'

  cocktails_details = cocktails_df[cocktails_df['Cocktail'].isin(recommendations.index)].set_index('Cocktail')

  recommendations_df = pd.concat([cocktails_details,recommendations], axis=1).sort_values(by='Similarity', ascending=False)

  return recommendations_df

# %%
# settings to display all columns
pd.options.display.max_colwidth = 80
pd.set_option("display.max_columns", None)

# %% [markdown]
# #### Enter reference drink

# %%
reference = 'Pina Colada'
mycocktail = cocktail_recommender(reference)
cocktails_df.loc[cocktails_df['Cocktail'] == reference]
# Out:
#         Cocktail                           Ingredients  \
# 999  Pina Colada  Pineapple, Coconut milk, Light rum,
#
#                                                                          Preparation  \
# 999  Mix with crushed ice in blender until smooth. Pour into chilled glass, garni...
#
#     Bar/Company Location
# 999

# %% [markdown]
# #### Output - First 10 corresponding drinks

# %%
cols = ['Ingredients', 'Similarity']
mycocktail[cols]
# Out:
#                                                                                                Ingredients  \
# Cocktail
# Havana Cocktail                                                  Lemon juice, Pineapple juice, Light rum,
# Frozen Pineapple Daiquiri                                        Sugar, Lime juice, Pineapple, Light rum,
# Jamaica Kiss                                                        Milk, Ice, Light rum, Coffee liqueur,
# 151 Florida Bushwacker     Vanilla ice-cream, Coconut liqueur, Milk, Cointreau, Dark Creme de Cacao, ru...
# Pink Colada                                             Pink Pigeon Rum, Pineapple Juice, Cream of Coconut
# Rum Milk Punch                                                   Nutmeg, Powdered sugar, Milk, Light rum,
# Rum Screwdriver                                                                  Orange juice, Light rum,
# Coco Batida                                         1 Coconut milk, 1 Condensed milk, Ypiòca, 1 Tbsp Sugar
# Arizona Twister            Pineapple, Orange Juice, Cream Of Coconut, Grenadine, Malibu Rum, Pineapple ...
# Cherry Rum                                                         Light cream, Cherry brandy, Light rum,
#
#                            Similarity
# Cocktail
# Havana Cocktail              0.589425
# Frozen Pineapple Daiquiri    0.575486
# Jamaica Kiss                 0.525381
# 151 Florida Bushwacker       0.510372
# Pink Colada                  0.509014
# Rum Milk Punch               0.474265
# Rum Screwdriver              0.472905
# Coco Batida                  0.449825
# Arizona Twister              0.445534
# Cherry Rum                   0.437334

# %%
cocktails_df['Ingredients'] = [x.strip(', ').split(',') for x in cocktails_df['Ingredients']]
cocktails_df['Ingredients']
# Out:
# 0                                                        [Creme De Cacao White,  Vodka]
# 1                                         [Light Rum,  Orange Juice,  Vodka,  Dark Rum]
# 2                 [Orange Curacao,  Strawberry Liqueur,  Orange Juice,  Absolut Citron]
# 3                             [Peach Schnapps,  Cranberry Juice,  Orange Juice,  Vodka]
# 4                                                [Lemon,  Maraschino Cherry,  Amaretto]
#                                              ...
# 1125                                                [Chambord raspberry liqueur,  Zima]
# 1126                                            [Lemon,  Ice,  Lemon juice,  Cointreau]
# 1127                                                      [Zima,  Midori melon liqueur]
# 1128                                                           [Apple juice,  Vermouth]
# 1129    [Lime,  Tabasco sauce,  Worcestershire sauce,  Lemon juice,  Tomato juice,  ...
# Name: Ingredients, Length: 1130, dtype: object
