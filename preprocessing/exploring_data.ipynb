# %% [markdown]
# Imports for data manipulation and Streaming of Cocktail DB with API

# %%
import numpy as np
import pandas as pd
import requests
import string

# %% [markdown]
# Based on method seen on: https://github.com/OzanGenc/CocktailAnalysis/blob/main/CocktailDbStreaming.ipynb

# %%
#The first 36 caharacters are the list of alphanumerical
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
def create_url_list():

  url_list = []
  main_url = 'https://www.thecocktaildb.com/api/json/v1/1/search.php?f='

  #for i in (string.printable[:36]):
  for i in (string.printable):

    url_list.append(main_url+i)

  return url_list

# %%
url_list = create_url_list()

# %%
def get_ingredients(cocktail_dict):

  ingredient = cocktail_dict['strIngredient1']
  i = 2

  ingredient_list = ""

  while ingredient:

    ingredient_list = ingredient + ", " + ingredient_list
    ingredient = cocktail_dict['strIngredient'+str(i)]
  
    i = i+1

  return ingredient_list

# %%
cocktails_list = []

for url in url_list:

  try:

    r = requests.get(url)

    if r.json()['drinks']:

      for cocktail_dict in r.json()['drinks']: 

        cocktail = {}
        cocktail['Cocktail Name'] = cocktail_dict['strDrink']
        cocktail['Ingredients'] = get_ingredients(cocktail_dict)
        cocktail['Preparation'] = cocktail_dict['strInstructions']

        cocktails_list.append(cocktail)

  except:
      pass

# %%
cocktail_df = pd.DataFrame(cocktails_list)

# %%
cocktail_df.drop_duplicates(inplace=True)

# %%
cocktail_df.to_csv('cocktails_db.csv', index=False)

# %% [markdown]
# ## Data exploration
# We put our 3 datasets into 3 different dataframes that we will try to merge into one.
# Sources:
# - data_cocktails.csv : https://www.kaggle.com/datasets/svetlanagruzdeva/cocktails-data
# - hotaling_cocktails.csv : https://www.kaggle.com/datasets/shuyangli94/cocktails-hotaling-co
# - cocktails_db.csv : https://www.thecocktaildb.com/

# %%
cocktails = pd.read_csv('data_cocktails.csv', index_col=0)
cocktails_h = pd.read_csv('hotaling_cocktails.csv')
cocktails_db = pd.read_csv('cocktails_db.csv')

# %%
cocktails.head(5)
# Out:
#                                strDrink strCategory             strGlass  \
# 0  '57 Chevy with a White License Plate    Cocktail       Highball glass
# 1  '57 Chevy with a White License Plate    Cocktail       Highball glass
# 2                        1-900-FUK-MEUP        Shot  Old-fashioned glass
# 3                        1-900-FUK-MEUP        Shot  Old-fashioned glass
# 4                        1-900-FUK-MEUP        Shot  Old-fashioned glass
#
#          strIngredients        Alc_type Basic_taste  \
# 0  Creme De Cacao White  Creamy Liqueur         NaN
# 1                 Vodka           Vodka         NaN
# 2         Grand Marnier      Triple Sec         NaN
# 3  Midori Melon Liqueur   Sweet Liqueur         NaN
# 4            Malibu Rum             Rum         NaN
#
#                                      strInstructions strMeasures  Value_ml  \
# 0  1. Fill a rocks glass with ice 2.add white cre...  1 oz white      30.0
# 1  1. Fill a rocks glass with ice 2.add white cre...        1 oz      30.0
# 2  Shake ingredients in a mixing tin filled with ...      1/4 oz       7.5
# 3  Shake ingredients in a mixing tin filled with ...      1/4 oz       7.5
# 4  Shake ingredients in a mixing tin filled with ...      1/4 oz       7.5
#
#    Value_gr Garnish_amount Garnish_type
# 0       NaN            NaN          NaN
# 1       NaN            NaN          NaN
# 2       NaN            NaN          NaN
# 3       NaN            NaN          NaN
# 4       NaN            NaN          NaN

# %%
cocktails_h.shape
# Out:
# (687, 9)

# %%
cocktails_db
# Out:
#                 Cocktail Name  \
# 0                 155 Belmont
# 1              1-900-FUK-MEUP
# 2            110 in the shade
# 3      151 Florida Bushwacker
# 4                         252
# ..                        ...
# 436              Zima Blaster
# 437            Zizi Coin-coin
# 438           Zimadori Zinger
# 439           Zippy's Revenge
# 440  Ziemes Martini Apfelsaft
#
#                                            Ingredients  \
# 0           Orange juice, Vodka, Light rum, Dark rum,
# 1    Pineapple juice, Cranberry juice, Amaretto, Ma...
# 2                                     Tequila, Lager,
# 3    Vanilla ice-cream, Coconut liqueur, Milk, Coin...
# 4                         Wild Turkey, 151 proof rum,
# ..                                                 ...
# 436                 Chambord raspberry liqueur, Zima,
# 437               Lemon, Ice, Lemon juice, Cointreau,
# 438                       Zima, Midori melon liqueur,
# 439                          Kool-Aid, Rum, Amaretto,
# 440                            Apple juice, Vermouth,
#
#                                            Preparation
# 0    Blend with ice. Serve in a wine glass. Garnish...
# 1    Shake ingredients in a mixing tin filled with ...
# 2                Drop shooter in glass. Fill with beer
# 3    Combine all ingredients. Blend until smooth. G...
# 4    Add both ingredients to shot glass, shoot, and...
# ..                                                 ...
# 436  Fill glass with ice. Pour in Chambord, then fi...
# 437  Pour 5cl of Cointreau on ice, add 2cl of fresh...
# 438  Pour Zima in a collins glass over ice and then...
# 439  Mix Kool-Aid to taste then add Rum and ammaret...
# 440  Serve without ice. At least the juice shold ha...
#
# [441 rows x 3 columns]

# %% [markdown]
# The goal is to merge all three in a **unique** dataset.
#
# We need to perform several cleaning operations and transformations. Especially deduplication.

# %% [markdown]
# #### 1. cocktails

# %%
cocktails = cocktails.drop(columns=['strGlass', 'Alc_type', 'Basic_taste', 'strMeasures', 'strMeasures', 
                                    'Value_ml', 'Value_gr', 'Garnish_amount', 'Garnish_type'])
cocktails
# Out:
#                                   strDrink   strCategory  \
# 0     '57 Chevy with a White License Plate      Cocktail
# 1     '57 Chevy with a White License Plate      Cocktail
# 2                           1-900-FUK-MEUP          Shot
# 3                           1-900-FUK-MEUP          Shot
# 4                           1-900-FUK-MEUP          Shot
# ...                                    ...           ...
# 1776                             Zorbatini      Cocktail
# 1777                             Zorbatini      Cocktail
# 1778                                 Zorro  Coffee / Tea
# 1779                                 Zorro  Coffee / Tea
# 1780                                 Zorro  Coffee / Tea
#
#              strIngredients                                    strInstructions
# 0      Creme De Cacao White  1. Fill a rocks glass with ice 2.add white cre...
# 1                     Vodka  1. Fill a rocks glass with ice 2.add white cre...
# 2             Grand Marnier  Shake ingredients in a mixing tin filled with ...
# 3      Midori Melon Liqueur  Shake ingredients in a mixing tin filled with ...
# 4                Malibu Rum  Shake ingredients in a mixing tin filled with ...
# ...                     ...                                                ...
# 1776                  Vodka  Prepare like a Martini. Garnish with a green o...
# 1777                   Ouzo  Prepare like a Martini. Garnish with a green o...
# 1778                Sambuca  add all and pour black coffee and add whipped ...
# 1779   Bailey'S Irish Cream  add all and pour black coffee and add whipped ...
# 1780  White Creme De Menthe  add all and pour black coffee and add whipped ...
#
# [1781 rows x 4 columns]

# %% [markdown]
# Main problem : grouping all ingredients into one unique Drink recipe row, like the other datasets

# %%
data_cocktails_new = cocktails.groupby('strDrink').agg(strCategory = ('strCategory', 'max'),
                                                    strIngredients =('strIngredients', ', '.join),
                                                    strInstructions = ('strInstructions', 'max')).reset_index()
data_cocktails_new
# Out:
#                                  strDrink           strCategory  \
# 0    '57 Chevy with a White License Plate              Cocktail
# 1                          1-900-FUK-MEUP                  Shot
# 2                        110 in the shade                  Beer
# 3                  151 Florida Bushwacker  Milk / Float / Shake
# 4                             155 Belmont              Cocktail
# ..                                    ...                   ...
# 468                            Zipperhead                  Shot
# 469                       Zippy's Revenge              Cocktail
# 470                        Zizi Coin-coin   Punch / Party Drink
# 471                             Zorbatini              Cocktail
# 472                                 Zorro          Coffee / Tea
#
#                                         strIngredients  \
# 0                          Creme De Cacao White, Vodka
# 1    Grand Marnier, Midori Melon Liqueur, Malibu Ru...
# 2                                       Tequila, Lager
# 3    Dark Creme De Cacao, Coconut Liqueur, Light Ru...
# 4             Light Rum, Orange Juice, Vodka, Dark Rum
# ..                                                 ...
# 468      Chambord Raspberry Liqueur, Soda Water, Vodka
# 469                      Rum, Kool-Aid Grape, Amaretto
# 470                      Cointreau, Lemon Juice, Lemon
# 471                                        Vodka, Ouzo
# 472  Sambuca, Bailey'S Irish Cream, White Creme De ...
#
#                                        strInstructions
# 0    1. Fill a rocks glass with ice 2.add white cre...
# 1    Shake ingredients in a mixing tin filled with ...
# 2                Drop shooter in glass. Fill with beer
# 3    Combine all ingredients. Blend until smooth. G...
# 4    Blend with ice. Serve in a wine glass. Garnish...
# ..                                                 ...
# 468  Fill glass with rocks, add straw before puttin...
# 469  Mix Kool-Aid to taste then add Rum and ammaret...
# 470  Pour 5cl of Cointreau on ice, add 2cl of fresh...
# 471  Prepare like a Martini. Garnish with a green o...
# 472  add all and pour black coffee and add whipped ...
#
# [473 rows x 4 columns]

# %% [markdown]
# Let's take only cocktails, filter out the rest.
# And then, input it into our future complete dataset.

# %%
data_cocktails_new = data_cocktails_new[data_cocktails_new['strCategory'] == "Cocktail"]
full_dataset = data_cocktails_new.drop(columns=['strCategory'])

# %%
full_dataset.rename(columns={'strDrink':"Cocktail", 'strIngredients':"Ingredients", 'strInstructions':"Preparation"}, inplace=True)

# %%
full_dataset.shape
# Out:
# (58, 3)

# %% [markdown]
# #### 2. cocktails_h

# %%
cocktails_h.head(5)
# Out:
#                Cocktail_Name          Bartender      Bar/Company  \
# 0             Flor de Amaras     Kelly McCarthy              NaN
# 1            The Happy Place  Elizabeth Montana  Forgery & Verso
# 2     Bon Voyage Pisco Punch        Jon Morales              NaN
# 3  Still Life of a Pineapple    Daniel Braganca          Backbar
# 4        The Bittered Valley         Nik Virrey              NaN
#
#         Location                                        Ingredients  \
# 0         Boston  1.5 oz Mezcal, 1 oz Hibiscus Simple Syrup*, .5...
# 1  San Francisco  2 oz Junipero Gin, .75 oz House-made Cranberry...
# 2  San Francisco  1500 ml BarSol Selecto Italia Pisco, 750 ml Le...
# 3     Somerville  1.5 oz BarSol Primero Quebranta Pisco, .75 oz ...
# 4        Seattle  1.25 oz Luxardo Maraschino Liqueur, 4 drops Ac...
#
#                                      Garnish   Glassware  \
# 0                            Marigold Petals         NaN
# 1  Dehydrated Lemon Wheel, Sprig of Rosemary         NaN
# 2                                        NaN  Punch Bowl
# 3                                        NaN         NaN
# 4                                        NaN         NaN
#
#                                          Preparation  \
# 0  *Hibiscus Simple Syrup:\n1:1 w/ a cup of dried...
# 1  *House-made Cranberry syrup: \n-- 2 cups Fresh...
# 2  *Pineapple Gomme: \nMix equal parts (1.5 cups)...
# 3  *Pineapple Syrup:\n<em>Equal parts pineapple b...
# 4  1st glass ingredients:\nLuxardo Maraschino, Ac...
#
#                                               Notes
# 0                                               NaN
# 1  Junipero Gin 20th Anniversary Signature Cocktail
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
cocktails_h = cocktails_h.drop(columns=['Bartender', 'Garnish', 'Glassware', 'Notes'])
cocktails_h.tail(5)
# Out:
#           Cocktail_Name           Bar/Company   Location  \
# 682  The Negroni Bianco                   NaN        NaN
# 683    Match Grip Julep           Death & Co.   New York
# 684      The Dry Cruise  Rob Roy, The Hideout    Seattle
# 685            Red Hook         Henrietta Red  Nashville
# 686          Union Jack      Union Lodge No.1     Denver
#
#                                            Ingredients Preparation
# 682  1.5 oz Luxardo Bitter Bianco, .75 oz Tempus Fu...         NaN
# 683  1.5 oz H by HINE, .5 oz Jamaican Rum, 1 tsp Ca...         NaN
# 684  1 oz Luxardo Bitter Bianco, 1 oz Lustau Oloros...         NaN
# 685  2 oz Rye Whiskey, 5 oz Punt e Mes, .5 oz Luxar...         NaN
# 686  .75 oz Luxardo Maraschino Liqueur, .75 oz Gree...         NaN

# %% [markdown]
# Get rid of dosage of ingredients to have consistent data: only ingredients.
# Regex tool used: https://regexr.com/

# %%
cocktails_h = cocktails_h.replace({'Preparation': r'\n'}, {'Preparation': ' '}, regex=True)
cocktails_h = cocktails_h.replace({'Ingredients': r'(.?[0-9].?\w*) [oz|ml|gr|drops|tsp]+ '}, {'Ingredients': ' '}, regex=True)

# %%
cocktails_h.rename(columns={'Cocktail_Name':"Cocktail"}, inplace=True)

# %%
full_dataset_new = pd.concat([full_dataset, cocktails_h], axis=0 ).reset_index()
full_dataset_new.drop(columns=['index'], inplace=True)
full_dataset_new
# Out:
#                                  Cocktail  \
# 0    '57 Chevy with a White License Plate
# 1                             155 Belmont
# 2                             9 1/2 Weeks
# 3                     A Gilligan's Island
# 4                    A True Amaretto Sour
# ..                                    ...
# 740                    The Negroni Bianco
# 741                      Match Grip Julep
# 742                        The Dry Cruise
# 743                              Red Hook
# 744                            Union Jack
#
#                                            Ingredients  \
# 0                          Creme De Cacao White, Vodka
# 1             Light Rum, Orange Juice, Vodka, Dark Rum
# 2    Orange Curacao, Strawberry Liqueur, Orange Jui...
# 3    Peach Schnapps, Cranberry Juice, Orange Juice,...
# 4                   Lemon, Maraschino Cherry, Amaretto
# ..                                                 ...
# 740   Luxardo Bitter Bianco,  Tempus Fugit Alessio ...
# 741   H by HINE,  Jamaican Rum, Cacao, Branca Menta...
# 742   Luxardo Bitter Bianco, Lustau Oloroso Sherry,...
# 743   Rye Whiskey, Punt e Mes,  Luxardo Maraschino ...
# 744   Luxardo Maraschino Liqueur,  Green Chartreuse...
#
#                                            Preparation           Bar/Company  \
# 0    1. Fill a rocks glass with ice 2.add white cre...                   NaN
# 1    Blend with ice. Serve in a wine glass. Garnish...                   NaN
# 2    Combine all ingredients in glass mixer. Chill ...                   NaN
# 3                                 Shaken, not stirred!                   NaN
# 4    Rub the rim of an old fashioned glass with lem...                   NaN
# ..                                                 ...                   ...
# 740                                                NaN                   NaN
# 741                                                NaN           Death & Co.
# 742                                                NaN  Rob Roy, The Hideout
# 743                                                NaN         Henrietta Red
# 744                                                NaN      Union Lodge No.1
#
#       Location
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 740        NaN
# 741   New York
# 742    Seattle
# 743  Nashville
# 744     Denver
#
# [745 rows x 5 columns]

# %%
full_dataset_new.drop_duplicates(subset="Cocktail", inplace=True)
full_dataset_new['Cocktail'].describe()
# Out:
# count                                      739
# unique                                     739
# top       '57 Chevy with a White License Plate
# freq                                         1
# Name: Cocktail, dtype: object

# %% [markdown]
# ### Create final dataset by combination

# %%
cocktails_db.rename(columns={"Cocktail Name": "Cocktail"}, inplace=True)
cocktails_db
# Out:
#                      Cocktail  \
# 0                 155 Belmont
# 1              1-900-FUK-MEUP
# 2            110 in the shade
# 3      151 Florida Bushwacker
# 4                         252
# ..                        ...
# 436              Zima Blaster
# 437            Zizi Coin-coin
# 438           Zimadori Zinger
# 439           Zippy's Revenge
# 440  Ziemes Martini Apfelsaft
#
#                                            Ingredients  \
# 0           Orange juice, Vodka, Light rum, Dark rum,
# 1    Pineapple juice, Cranberry juice, Amaretto, Ma...
# 2                                     Tequila, Lager,
# 3    Vanilla ice-cream, Coconut liqueur, Milk, Coin...
# 4                         Wild Turkey, 151 proof rum,
# ..                                                 ...
# 436                 Chambord raspberry liqueur, Zima,
# 437               Lemon, Ice, Lemon juice, Cointreau,
# 438                       Zima, Midori melon liqueur,
# 439                          Kool-Aid, Rum, Amaretto,
# 440                            Apple juice, Vermouth,
#
#                                            Preparation
# 0    Blend with ice. Serve in a wine glass. Garnish...
# 1    Shake ingredients in a mixing tin filled with ...
# 2                Drop shooter in glass. Fill with beer
# 3    Combine all ingredients. Blend until smooth. G...
# 4    Add both ingredients to shot glass, shoot, and...
# ..                                                 ...
# 436  Fill glass with ice. Pour in Chambord, then fi...
# 437  Pour 5cl of Cointreau on ice, add 2cl of fresh...
# 438  Pour Zima in a collins glass over ice and then...
# 439  Mix Kool-Aid to taste then add Rum and ammaret...
# 440  Serve without ice. At least the juice shold ha...
#
# [441 rows x 3 columns]

# %%
final_df = pd.concat([full_dataset_new, cocktails_db], axis=0).reset_index()

# %%
final_df.drop_duplicates(subset="Cocktail", inplace=True)
final_df['Cocktail'].describe()
# Out:
# count                                     1129
# unique                                    1129
# top       '57 Chevy with a White License Plate
# freq                                         1
# Name: Cocktail, dtype: object

# %%
final_df.drop(columns=['index'], inplace=True)
final_df
# Out:
#                                   Cocktail  \
# 0     '57 Chevy with a White License Plate
# 1                              155 Belmont
# 2                              9 1/2 Weeks
# 3                      A Gilligan's Island
# 4                     A True Amaretto Sour
# ...                                    ...
# 1174                            Zipperhead
# 1175                          Zima Blaster
# 1176                        Zizi Coin-coin
# 1177                       Zimadori Zinger
# 1179              Ziemes Martini Apfelsaft
#
#                                             Ingredients  \
# 0                           Creme De Cacao White, Vodka
# 1              Light Rum, Orange Juice, Vodka, Dark Rum
# 2     Orange Curacao, Strawberry Liqueur, Orange Jui...
# 3     Peach Schnapps, Cranberry Juice, Orange Juice,...
# 4                    Lemon, Maraschino Cherry, Amaretto
# ...                                                 ...
# 1174    Soda water, Vodka, Chambord raspberry liqueur,
# 1175                 Chambord raspberry liqueur, Zima,
# 1176               Lemon, Ice, Lemon juice, Cointreau,
# 1177                       Zima, Midori melon liqueur,
# 1179                            Apple juice, Vermouth,
#
#                                             Preparation Bar/Company Location
# 0     1. Fill a rocks glass with ice 2.add white cre...         NaN      NaN
# 1     Blend with ice. Serve in a wine glass. Garnish...         NaN      NaN
# 2     Combine all ingredients in glass mixer. Chill ...         NaN      NaN
# 3                                  Shaken, not stirred!         NaN      NaN
# 4     Rub the rim of an old fashioned glass with lem...         NaN      NaN
# ...                                                 ...         ...      ...
# 1174  Fill glass with rocks, add straw before puttin...         NaN      NaN
# 1175  Fill glass with ice. Pour in Chambord, then fi...         NaN      NaN
# 1176  Pour 5cl of Cointreau on ice, add 2cl of fresh...         NaN      NaN
# 1177  Pour Zima in a collins glass over ice and then...         NaN      NaN
# 1179  Serve without ice. At least the juice shold ha...         NaN      NaN
#
# [1129 rows x 5 columns]

# %%
final_df = final_df.replace({'Ingredients': r'(.?[0-9].?\w*) [oz|ml|gr|drops|tsp|dash|c|float|bsp]+ '}, {'Ingredients': ' '}, regex=True)

# %%
final_df['Cocktail'].str.strip()
final_df['Ingredients'].str.strip(', ')
final_df['Preparation'].str.strip()
# Out:
# 0       1. Fill a rocks glass with ice 2.add white cre...
# 1       Blend with ice. Serve in a wine glass. Garnish...
# 2       Combine all ingredients in glass mixer. Chill ...
# 3                                    Shaken, not stirred!
# 4       Rub the rim of an old fashioned glass with lem...
#                               ...
# 1174    Fill glass with rocks, add straw before puttin...
# 1175    Fill glass with ice. Pour in Chambord, then fi...
# 1176    Pour 5cl of Cointreau on ice, add 2cl of fresh...
# 1177    Pour Zima in a collins glass over ice and then...
# 1179    Serve without ice. At least the juice shold ha...
# Name: Preparation, Length: 1129, dtype: object

# %%
new_row = pd.Series({'Cocktail': "Bloody Mary", 'Ingredients': "Lime, Tabasco sauce, Worcestershire sauce, Lemon juice, Tomato juice, Vodka",
                        'Preparation' : "Stirring gently, pour all ingredients into highball glass. Garnish."})
final_df = pd.concat([final_df, new_row.to_frame().T], ignore_index=True)

# %% [markdown]
# #### Export final dataset

# %%
final_df.to_csv('final_cocktails.csv', encoding='UTF-8', index=False)
